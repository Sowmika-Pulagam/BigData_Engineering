# %% [markdown]
# #### SQL And SQLite
# SQL (Structured Query Language) is a standard language for managing and manipulating relational databases. SQLite is a self-contained, serverless, and zero-configuration database engine that is widely used for embedded database systems. In this lesson, we will cover the basics of SQL and SQLite, including creating databases, tables, and performing various SQL operations.

# %%
import sqlite3 ## CRUD: Create, Read, Update, Delete

# %%
## Connect to an SQLite database

connection = sqlite3.connect('example.db')
connection

# %%
# cursor: Executes SQL statements (SELECT, INSERT, UPDATE, DELETE, etc.). Retrieves query results row-by-row or all at once. Keeps track of the current position in the result set.
cursor1 = connection.cursor()
cursor1

# %%
## Create a Table from cursor1

cursor1.execute('''
Create Table If Not Exists employees(
    id Integer Primary Key,
    name Text Not Null,
    age Integer,
    department text
    )
''')

## Commit the changes
connection.commit()

# %%
cursor1.execute('''
Select * from employees
''')

# %%
## Insert the data in sqlite table

cursor1.execute(''' Insert into employees(name, age, department)
                    values('Sow', 25, 'Engineer')  
''')

cursor1.execute(''' Insert into employees(name, age, department)
                    values('Vee', 31, 'Developer')
               
''')

cursor1.execute(''' Insert into employees(name, age, department)
                    values('Tran', 40, 'Manager')
               
''')

## Conection commit

## Commit the changes
connection.commit()

# %%
## Query the data from the employees table

cursor1.execute('select * from employees')

## to get all the records we use the fetchall
rows = cursor1.fetchall()

## print the queried data
for row in rows:
    print(row)
# Out:
# (1, 'Krish', 34, 'Data Scientist')
# (3, 'Charlie', 35, 'Finance')
# (4, 'Sow', 25, 'Engineer')
# (5, 'Vee', 31, 'Developer')
# (6, 'Tran', 40, 'Manager')
# (7, 'Sow', 25, 'Engineer')
# (8, 'Vee', 31, 'Developer')
# (9, 'Tran', 40, 'Manager')
# (10, 'Sow', 25, 'Engineer')
# (11, 'Vee', 31, 'Developer')
# (12, 'Tran', 40, 'Manager')

# %%
## Update the data in the employees table
cursor1.execute('''
UPDATE employees 
SET age = 34
WHERE name = "Krish" 
                ''')

# %%
## Commit the changes
connection.commit()

# %%
## Query the data from the table
cursor1.execute('''select * from employees''')
rows = cursor1.fetchall()

for i in rows:
    print(i)
# Out:
# (1, 'Krish', 34, 'Data Scientist')
# (3, 'Charlie', 35, 'Finance')
# (4, 'Sow', 25, 'Engineer')
# (5, 'Vee', 31, 'Developer')
# (6, 'Tran', 40, 'Manager')
# (7, 'Sow', 25, 'Engineer')
# (8, 'Vee', 31, 'Developer')
# (9, 'Tran', 40, 'Manager')
# (10, 'Sow', 25, 'Engineer')
# (11, 'Vee', 31, 'Developer')
# (12, 'Tran', 40, 'Manager')

# %%
## Delete the data from the table
cursor1.execute('''DELETE FROM employees
                WHERE name = 'Bob'
''')

cursor1.execute('''DELETE FROM employees
                WHERE name = 'Charlie'
''')

cursor1.execute('''DELETE FROM employees
                WHERE name = 'Tran'
''')
## Commit the changes
connection.commit()

# %%
## Query the data from the table
cursor1.execute('Select * from employees')
rows=cursor1.fetchall()

## print the queried data
for row in rows:
    print(row)
# Out:
# (1, 'Krish', 34, 'Data Scientist')
# (4, 'Sow', 25, 'Engineer')
# (5, 'Vee', 31, 'Developer')
# (7, 'Sow', 25, 'Engineer')
# (8, 'Vee', 31, 'Developer')
# (10, 'Sow', 25, 'Engineer')
# (11, 'Vee', 31, 'Developer')

# %%
## Working Wwith Sales Data
# Connect to an SQLite database
connection1 = sqlite3.connect('sales_data.db')
cursor = connection.cursor()

# Create a table for sales data
cursor.execute('''
CREATE TABLE IF NOT EXISTS sales(
               id integer PRIMARY KEY,
               date TEXT NOT NULL,
               product TEXT NOT NULL,
               sales INTEGER,
               region TEXT)
''')

# %%
# Insert data into the sales table
sales_data = [
    ('2023-01-01', 'Product1', 100, 'North'),
    ('2023-01-02', 'Product2', 200, 'South'),
    ('2023-01-03', 'Product1', 150, 'East'),
    ('2023-01-04', 'Product3', 250, 'West'),
    ('2023-01-05', 'Product2', 300, 'North')
]

# %%
# to execute in bulk
cursor.executemany('''Insert into sales(date,product,sales,region)
                   values(?,?,?,?)'''
                   ,sales_data)

connection.commit()

# %%
# Query data from the sales table
cursor.execute('SELECT * FROM sales')
rows = cursor.fetchall()

# Print the queried data
for row in rows:
    print(row)
# Out:
# (1, '2023-01-01', 'Product1', 100, 'North')
# (2, '2023-01-02', 'Product2', 200, 'South')
# (3, '2023-01-03', 'Product1', 150, 'East')
# (4, '2023-01-04', 'Product3', 250, 'West')
# (5, '2023-01-05', 'Product2', 300, 'North')

# %%
## close the connection
connection.close()

# %%
# Query data from the sales table
cursor.execute('SELECT * FROM sales')
rows = cursor.fetchall()

# Print the queried data
for row in rows:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Query data from the sales table
# ----> 2 cursor.execute('SELECT * FROM sales')
#       3 rows = cursor.fetchall()
#       5 # Print the queried data
#
# ProgrammingError: Cannot operate on a closed database.
