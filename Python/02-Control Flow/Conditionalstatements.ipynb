# %% [markdown]
# #### Conditional Statements (if, elif, else, Nested)

# %%
## if statement: if statement evaluates a condition and executes the block of code within it, if the condition is true

age = 20
if age >= 18:
    print("You are an adult.")
# Out:
# You are an adult.

# %%
## else: the else statement executes a block of code if the condition in the if statement is False.
age = 16
if age >= 18:
    print("You are an adult.")
else:
    print("You are a minor.")
# Out:
# You are a minor.

# %%
## elif: the elif statement allows you to check multiple conditions. It stands for "else if"
age = 17
if age < 13:
    print("You are an child")
elif age < 18:
    print("You are a teenager.")
else:
    print("You are an adult.")
# Out:
# You are a teenager.

# %%
## Nested Conditional Statements: You can place one or more if, elif, or else statements inside another if, elif, or else statement to create nested conditional statements.

num = int(input("enter a number: "))
if num >= 0:
    print("The number is positive")

    if num % 2 == 0:
        print("The number is even")

    else:
        print("The number is odd")

else:
    print("The number is zero or negative")
# Out:
# The number is positive
# The number is even

# %%
## Practical Examples: Determine if a year is a leap year using nested condition statement

year = int(input("Enter a year:"))

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("f{year}, This is a leap year")
        else:
            print(f"{year}, This is not a leap year")
    
    else:
        print(f"{year}, This is a leap year")
    
else:
    print(f"{year}, This is not a leap year")
# Out:
# 2024, This is a leap year

# %%
# Simple Calculator
num1 = float(input("Enter a first number:"))
num2 = float(input("Enter a second number:"))
operation = input("Enter operation (+, -, *, /): ")

if operation == "+":
    result = num1 + num2
    print(f"{num1} + {num2} = {result}")

elif operation == "-":
    result = num1 - num2
    print(f"{num1} - {num2} = {result}")

elif operation == "*":
    result = num1 * num2
    print(f"{num1} * {num2} = {result}")

elif operation == "/":
    if num2 != 0:
        result = num1 / num2
    else:
        print("Error: Division by zero is not allowed.")

else:
    print("Invalid operation")
# Out:
# 5.0 - 18.0 = -13.0

# %%
# Determining the ticket price based on age and whether the person is a student.
# Ticket pricing based on age and student status

age = int(input("Enter your age: "))
is_student = input("Are you a student? (yes/no):").lower()

if age < 5:
    print("Free")
elif age <= 12:
    print("Child ticket: $10")

elif age <= 17:
    if is_student == "yes":
        print("Student ticket: $12")
    else:
        print("Teen ticket: $15")

elif age <= 65:
    if is_student == 'yes':
        print("Student ticket: $18")
    else:
        print("Student ticket: $25")
# Out:
# Student ticket: $18
